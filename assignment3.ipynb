# %%
import pandas as pd;
import matplotlib as plt;
import seaborn as sn;

# %%
df = pd.read_csv('iris.data.csv');

# %%
df
# Out:
#       x1   x2   x3   x4            Type
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
b = df.corr(numeric_only=True)
print("correlation is :\n" ,b)
# Out:
# correlation is :
#            x1        x2        x3        x4
# x1  1.000000 -0.109369  0.871754  0.817954
# x2 -0.109369  1.000000 -0.420516 -0.356544
# x3  0.871754 -0.420516  1.000000  0.962757
# x4  0.817954 -0.356544  0.962757  1.000000

# %%
b.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
b.style.background_gradient(cmap ='coolwarm')
# Out:
# <style type="text/css">
# #T_26598_row0_col0, #T_26598_row1_col1, #T_26598_row2_col2, #T_26598_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_26598_row0_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_26598_row0_col2 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_26598_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_26598_row1_col0, #T_26598_row1_col2, #T_26598_row1_col3, #T_26598_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_26598_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_26598_row2_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_26598_row3_col0 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_26598_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_26598_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_26598">
#   <thead>
#     <tr>
# ...

# %%
sn.heatmap(b,annot=True)
# Out:
# <Axes: >

# %%
df[['x1', 'x2','x3','x4']].cov()
# Out:
#           x1        x2        x3        x4
# x1  0.685694 -0.039268  1.273682  0.516904
# x2 -0.039268  0.188004 -0.321713 -0.117981
# x3  1.273682 -0.321713  3.113179  1.296387
# x4  0.516904 -0.117981  1.296387  0.582414

# %%
df[['x1','x2','x3','x4']].var()
# Out:
# x1    0.685694
# x2    0.188004
# x3    3.113179
# x4    0.582414
# dtype: float64
